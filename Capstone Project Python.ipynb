# %% [markdown]
# # Task 1. Load the movies dataset in the python notebook. Display the title genere of the first 50 movies from the data set.

# %%
import pandas as pd

# Open the file
df = pd.read_csv(r"DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")

# %%
print(df)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [raw]
# Task - 1: Load the movie dataset in the Python notebook. Display the numbers of rows and columns in the dataset. Display the titles and genres of the first 50 movies from the dataset.

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
import pandas as pd

# Open the file
df = pd.read_csv(r"DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")

# Display the number of rows and columns
print(df.shape)
# Out:
# (4803, 20)

# %%
# Import pandas as pd
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv(r"DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")

# Select the first 50 rows of the DataFrame
first_50_movies = df.head(50)

# Display the titles and genres of the first 50 movies
print(first_50_movies[['title', 'genres']])
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# # Task-2: Identify the columns that have null values and perform the null value treatment. (Choose the imputation method based on the type of data in the columns of interest)

# %%
# Check for null values in each column
null_values = df.isnull().sum()

# %%
# Identify the columns that have null values
columns_with_null_values = null_values[null_values > 0].index

# %%
# Perform the null value treatment based on the type of data in the columns of interest
for column in columns_with_null_values:
    if df[column].dtype == 'object':
        # Impute missing values with the most frequent value in the column
        df[column] = df[column].fillna(df[column].mode()[0])
    elif df[column].dtype == 'int64' or df[column].dtype == 'float64':
        # Impute missing values with the mean of the column
        df[column] = df[column].fillna(df[column].mean())

# Check for null values again after the treatment
null_values_after_treatment = df.isnull().sum()

# Print the columns that still have null values
columns_with_null_values_after_treatment = null_values_after_treatment[null_values_after_treatment > 0].index

print("Columns with null values before treatment:", columns_with_null_values)
print("Columns with null values after treatment:", columns_with_null_values_after_treatment)
# Out:
# Columns with null values before treatment: Index(['homepage', 'overview', 'release_date', 'runtime', 'tagline'], dtype='object')
# Columns with null values after treatment: Index([], dtype='object')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# budget                  0
# genres                  0
# vote_average            0
# title                   0
# tagline                 0
# status                  0
# spoken_languages        0
# runtime                 0
# revenue                 0
# release_date            0
# production_countries    0
# production_companies    0
# popularity              0
# overview                0
# original_title          0
# original_language       0
# keywords                0
# id                      0
# homepage                0
# vote_count              0
# dtype: int64

# %% [markdown]
# # Task - 3: Display the movie categories that have a budget greater than $220,000.

# %%
# Filter for movies with budget greater than $220,000
x=filtered_df = df[df['budget'] > 220000]

# %%
print(x)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4680     450000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4682   13000000                     [{"id": 27, "name": "Horror"}]
# 4720    8500000                      [{"id": 18, "name": "Drama"}]
# 4758    4000000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 4770     500000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # Task - 4: Display the movie categories where the revenue is greater than $961,000,000.

# %%
# Filter movies with revenue greater than $961,000,000
y=filtered_df = df[df['revenue'] > 961000000]

# %%
print (y)
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 12   200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17   380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 32   200000000  [{"id": 10751, "name": "Family"}, {"id": 14, "...
# 36   210000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# ...

# %% [markdown]
# # Task-5: In the dataset, there are some movies for which the budget and revenue columns have the
#
# value 0, which mean unknown values. Remove the rows with value 0 from both the budget and revenue columns.

# %%
# Filter rows with values other than 0 in both budget and revenue columns
filtered_df = df[((df["budget"] != 0) & (df["revenue"] != 0))]

# Display the filtered DataFrame
print(filtered_df)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # Task - 6: List the top 10 movies with the highest revenues and the top 10 movies with the least budget.

# %%
# Sort movies by revenue in descending order
revenue_sorted_df = df.sort_values(by='revenue', ascending=False)

# Select the top 10 movies with the highest revenues
top_10_highest_revenue_movies = revenue_sorted_df.head(10)

# Sort movies by budget in ascending order
budget_sorted_df = df.sort_values(by='budget')

# Select the top 10 movies with the least budget
top_10_least_budget_movies = budget_sorted_df.head(10)

print("Top 10 movies with the highest revenues:")
print(top_10_highest_revenue_movies)

print("\nTop 10 movies with the least budget:")
print(top_10_least_budget_movies)
# Out:
# Top 10 movies with the highest revenues:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44   190000000                     [{"id": 28, "name": "Action"}]
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 124  150000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 25                         http://www.titanicmovie.com     597
# ...

# %%
print("\nTop 10 movies with the least budget:")
print(top_10_least_budget_movies)
# Out:
# Top 10 movies with the least budget:
#       budget                                             genres  \
# 2401       0                   [{"id": 53, "name": "Thriller"}]
# 3187       0  [{"id": 35, "name": "Comedy"}, {"id": 10402, "...
# 3183       0  [{"id": 10749, "name": "Romance"}, {"id": 18, ...
# 3179       0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 3178       0                      [{"id": 18, "name": "Drama"}]
# 3176       0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 3157       0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 3156       0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 3154       0  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 3152       0  [{"id": 18, "name": "Drama"}, {"id": 10752, "n...
#
#                                       homepage      id  \
# 2401         http://www.missionimpossible.com/   31932
# 3187         http://www.missionimpossible.com/   12621
# ...

# %% [markdown]
# # Task-7: How are popularities of movies related with the movie budgets? Are they correlated or totally uncorrelated with each other? Write the interpretation of your analysis.

# %%
# Compute the correlation coefficient between popularity and budget
correlation_coefficient = df['popularity'].corr(df['budget'])

# %%
print("Correlation coefficient between popularity and budget:", correlation_coefficient)
# Out:
# Correlation coefficient between popularity and budget: 0.5054139990665325

# %% [raw]
# The correlation coefficient between popularity and budget is 0.505. This means that there is a positive correlation between the two variables. In other words, as the budget of a movie increases, its popularity also tends to increase.

# %%
import pandas as pd
import numpy as np

# Read the CSV file into a DataFrame
df = pd.read_csv(r"DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")

# Calculate the mean of the 'budget' column
mean_budget = df['budget'].mean()

# Calculate the standard deviation of the 'revenue' column
std_revenue = df['revenue'].std()

# Calculate the correlation coefficient between 'popularity' and 'budget'
correlation_coefficient = df['popularity'].corr(df['budget'])

# Display the results
print("Mean budget:", mean_budget)
print("Standard deviation of revenue:", std_revenue)
print("Correlation coefficient between popularity and budget:", correlation_coefficient)
# Out:
# Mean budget: 29045039.87528628
# Standard deviation of revenue: 162857100.94282603
# Correlation coefficient between popularity and budget: 0.5054139990665325

# %% [markdown]
# # Task-8: Identify and display the names of all production companies along with the number of times they appear in the dataset.

# %%
# Extract production company names from the 'production_companies' column
production_company_names = df['production_companies'].str.split(', ').explode().unique()

# Create a Series to store production company counts
production_company_counts = df['production_companies'].value_counts()

# Display the production company names and their counts
print("Production Company Counts:")
print(production_company_counts)
len(production_company_counts)
# Out:
# Production Company Counts:
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              351
# ...

# %% [markdown]
# # Task-9: Display the names of the top 25 production companies based on the number of movies they have produced in descending order of the number of movies produced.

# %%
# Extract production company names from the `production_companies` column
production_company_names = df['production_companies'].str.split(', ').explode().unique()

# Create a Series to store production company counts
production_company_counts = df['production_companies'].value_counts()

# Sort production company counts in descending order
sorted_production_company_counts = production_company_counts.sort_values(ascending=False)

# Select the top 25 production companies
top_25_production_companies = sorted_production_company_counts.index[:25]

# Display the names of the top 25 production companies
print("Top 25 Production Companies by Movie Count:")
print(top_25_production_companies)
# Out:
# Top 25 Production Companies by Movie Count:
# Index(['[]', '[{"name": "Paramount Pictures", "id": 4}]',
#        '[{"name": "Universal Pictures", "id": 33}]',
#        '[{"name": "New Line Cinema", "id": 12}]',
#        '[{"name": "Columbia Pictures", "id": 5}]',
#        '[{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 8411}]',
#        '[{"name": "Twentieth Century Fox Film Corporation", "id": 306}]',
#        '[{"name": "Warner Bros.", "id": 6194}]',
#        '[{"name": "Walt Disney Pictures", "id": 2}]',
#        '[{"name": "Touchstone Pictures", "id": 9195}]',
#        '[{"name": "Dimension Films", "id": 7405}]',
#        '[{"name": "Columbia Pictures Corporation", "id": 441}]',
#        '[{"name": "Miramax Films", "id": 14}]',
#        '[{"name": "DreamWorks Animation", "id": 521}]',
#        '[{"name": "United Artists", "id": 60}]',
#        '[{"name": "Walt Disney Pictures", "id": 2}, {"name": "Pixar Animation Studios", "id": 3}]',
# ...

# %% [markdown]
# # Task-10: Sort the data in descending order based on revenue and filter the top 500 movies. Find the measures of central tendency for the following columns using the filtered data:
#
# 1. budget
#
# 2. revenue
#
# 3. runtime
#
# Perform outlier analysis for the above three columns using box plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset
data = pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')

# Filter the top 500 movies based on revenue in descending order
filtered_data = data.sort_values(by='revenue', ascending=False).head(500)

# Calculate measures of central tendency for the filtered data
budget_mean = filtered_data['budget'].mean()
revenue_mean = filtered_data['revenue'].mean()
runtime_mean = filtered_data['runtime'].mean()

budget_median = filtered_data['budget'].median()
revenue_median = filtered_data['revenue'].median()
runtime_median = filtered_data['runtime'].median()

budget_mode = filtered_data['budget'].mode()[0]
revenue_mode = filtered_data['revenue'].mode()[0]
runtime_mode = filtered_data['runtime'].mode()[0]

# Print the measures of central tendency
print("Measures of Central Tendency:")
print("Budget:")
print(f"Mean: {budget_mean}")
print(f"Median: {budget_median}")
print(f"Mode: {budget_mode}")

print("\nRevenue:")
print(f"Mean: {revenue_mean}")
print(f"Median: {revenue_median}")
print(f"Mode: {revenue_mode}")

print("\nRuntime:")
print(f"Mean: {runtime_mean}")
print(f"Median: {runtime_median}")
print(f"Mode: {runtime_mode}")

# Perform outlier analysis for budget, revenue, and runtime using box plots
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.boxplot(filtered_data['budget'])
plt.title("Budget")

plt.subplot(1, 3, 2)
plt.boxplot(filtered_data['revenue'])
plt.title("Revenue")

plt.subplot(1, 3, 3)
plt.boxplot(filtered_data['runtime'])
plt.title("Runtime")

plt.tight_layout()
plt.show()
# Out:
# Measures of Central Tendency:
# Budget:
# Mean: 102803736.0
# Median: 95000000.0
# Mode: 150000000
#
# Revenue:
# Mean: 458722133.294
# Median: 363001569.5
# Mode: 219076518
#
# Runtime:
# Mean: 118.626
# Median: 116.0
# Mode: 115.0

# %% [markdown]
# # Task-11: Identify and display the names of the movies along with their run times for those movies that have above average runtime, using the data from the previous task.

# %%
# Find movies with above-average runtime
above_average_runtime_movies = data[data['runtime'] > data['runtime'].mean()]

# Display movie titles and runtimes
print("Movies with Above-Average Runtime:")
print(above_average_runtime_movies[['original_title', 'runtime']])
# Out:
# Movies with Above-Average Runtime:
#                                 original_title  runtime
# 0                                       Avatar    162.0
# 1     Pirates of the Caribbean: At World's End    169.0
# 2                                      Spectre    148.0
# 3                        The Dark Knight Rises    165.0
# 4                                  John Carter    132.0
# ...                                        ...      ...
# 4770                       Mutual Appreciation    109.0
# 4782                                  Flywheel    120.0
# 4789                                     Clean    111.0
# 4792                                       キュア    111.0
# 4800                 Signed, Sealed, Delivered    120.0
#
# [2079 rows x 2 columns]
